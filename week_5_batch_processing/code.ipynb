# %% [markdown]
# ## Seting up PySpark

# %%
# Import libraries
import pandas as pd
import pyspark
import findspark
from pyspark.sql import SparkSession
from pyspark.sql import types
from pyspark.sql import functions as F

# Ensure that pyspark is available and that the environment variables are set
findspark.init()

# %%
# Create a SparkSession
spark = SparkSession.builder \
    .master("local[*]") \
    .appName('test') \
    .getOrCreate()

# %%
# Read data and print schema
df = spark.read.parquet('fhvhv/2021/01/')
df.printSchema()
# Out:
# root
#  |-- hvfhs_license_num: string (nullable = true)
#  |-- dispatching_base_num: string (nullable = true)
#  |-- originating_base_num: string (nullable = true)
#  |-- request_datetime: timestamp (nullable = true)
#  |-- on_scene_datetime: timestamp (nullable = true)
#  |-- pickup_datetime: timestamp (nullable = true)
#  |-- dropoff_datetime: timestamp (nullable = true)
#  |-- PULocationID: long (nullable = true)
#  |-- DOLocationID: long (nullable = true)
#  |-- trip_miles: double (nullable = true)
#  |-- trip_time: long (nullable = true)
#  |-- base_passenger_fare: double (nullable = true)
#  |-- tolls: double (nullable = true)
#  |-- bcf: double (nullable = true)
#  |-- sales_tax: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- airport_fee: double (nullable = true)
#  |-- tips: double (nullable = true)
#  |-- driver_pay: double (nullable = true)
#  |-- shared_request_flag: string (nullable = true)
#  |-- shared_match_flag: string (nullable = true)
#  |-- access_a_ride_flag: string (nullable = true)
#  |-- wav_request_flag: string (nullable = true)
#  |-- wav_match_flag: string (nullable = true)

# %%
# A crazy function that changes values when they're divisible by 7 or 3
def crazy_stuff(base_num):
    num = int(base_num[1:])
    if num % 7 == 0:
        return f's/{num:03x}'
    elif num % 3 == 0:
        return f'a/{num:03x}'
    else:
        return f'e/{num:03x}'

# Creating the actual UDF
crazy_stuff_udf = F.udf(crazy_stuff, returnType=types.StringType())

# Using the UDF
df.withColumn('pickup_date', F.to_date(df.pickup_datetime)) \
    .withColumn('dropoff_date', F.to_date(df.dropoff_datetime)) \
    .withColumn('base_id', crazy_stuff_udf(df.dispatching_base_num)) \
    .select('base_id', 'pickup_date', 'dropoff_date', 'PULocationID', 'DOLocationID') \
    .show()
# Out:
# +-------+-----------+------------+------------+------------+
# |base_id|pickup_date|dropoff_date|PULocationID|DOLocationID|
# +-------+-----------+------------+------------+------------+
# |  e/acc| 2021-01-11|  2021-01-11|         262|         231|
# |  e/a39| 2021-01-05|  2021-01-05|          61|         181|
# |  e/9ce| 2021-01-02|  2021-01-02|         100|           1|
# |  e/b42| 2021-01-31|  2021-01-31|         232|           4|
# |  s/af0| 2021-01-05|  2021-01-05|         162|           1|
# |  a/b43| 2021-01-27|  2021-01-27|          68|          68|
# |  e/9ce| 2021-01-18|  2021-01-18|         205|         205|
# |  e/b35| 2021-01-30|  2021-01-30|         256|         255|
# |  e/b3b| 2021-01-16|  2021-01-16|          89|          91|
# |  e/9ce| 2021-01-05|  2021-01-05|         132|         102|
# |  e/acc| 2021-01-11|  2021-01-11|          97|          61|
# |  e/9ce| 2021-01-22|  2021-01-22|          79|          37|
# |  e/b32| 2021-01-03|  2021-01-03|          26|         178|
# |  a/b49| 2021-01-14|  2021-01-14|         181|         198|
# |  e/acc| 2021-01-08|  2021-01-08|          76|          91|
# |  e/b3c| 2021-01-15|  2021-01-15|         246|          16|
# |  s/b36| 2021-01-27|  2021-01-27|         135|          73|
# |  e/9ce| 2021-01-18|  2021-01-18|          74|         234|
# |  e/a39| 2021-01-11|  2021-01-11|          68|         211|
# |  e/b3f| 2021-01-24|  2021-01-24|         249|         236|
# +-------+-----------+------------+------------+------------+
# only showing top 20 rows

# %%
spark.stop()

# %% [markdown]
# ## PySpark SQL

# %%
# Load libraries and create SparkSession
# Import libraries
import pandas as pd
import pyspark
import findspark
from pyspark.sql import SparkSession
from pyspark.sql import types
from pyspark.sql import functions as F

# Ensure that pyspark is available and that the environment variables are set
findspark.init()

# Create a SparkSession
spark = SparkSession.builder \
    .master("local[*]") \
    .appName('pyspark-sql') \
    .getOrCreate()

# %%
# Read parquet files
df_green = spark.read.parquet("data/pq/green/*/*")
df_yellow = spark.read.parquet("data/pq/yellow/*/*")
# Out:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- lpep_pickup_datetime: timestamp (nullable = true)
#  |-- lpep_dropoff_datetime: timestamp (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- RatecodeID: integer (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- passenger_count: integer (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- ehail_fee: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_type: integer (nullable = true)
#  |-- trip_type: integer (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)

# %%
# Rename columns to match pickup_datetime and dropoff_datetime
df_green = df_green \
    .withColumnRenamed("lpep_pickup_datetime", "pickup_datetime") \
    .withColumnRenamed("lpep_dropoff_datetime", "dropoff_datetime")

df_yellow = df_yellow \
    .withColumnRenamed("tpep_pickup_datetime", "pickup_datetime") \
    .withColumnRenamed("tpep_dropoff_datetime", "dropoff_datetime")

# %%
# Get common columns in both dataframes in original order
common_cols = [col for col in df_green.columns if col in df_yellow.columns]
# Select common columns in both dataframes
df_green_mod = df_green.select(common_cols)
df_yellow_mod = df_yellow.select(common_cols)
# Establish service type in each dataframe
df_green_mod = df_green_mod.withColumn("service_type", F.lit("green"))
df_yellow_mod = df_yellow_mod.withColumn("service_type", F.lit("yellow"))
# Combine dataframes
trips_data = df_green_mod.unionAll(df_yellow_mod)
# Count records by service type
trips_data.groupBy("service_type").count().show()
# Out:
# +------------+--------+
# |service_type|   count|
# +------------+--------+
# |       green| 2304517|
# |      yellow|39649199|
# +------------+--------+

# %%
# Register the DataFrame as a temporary table
trips_data.registerTempTable("trips_data")
# Run a SQL query
spark.sql("""
SELECT 
    service_type,
    count(1) as record_count
FROM
    trips_data
GROUP BY
    service_type
""").show()
# Out:
# +------------+------------+
# |service_type|record_count|
# +------------+------------+
# |       green|     2304517|
# |      yellow|    39649199|
# +------------+------------+

# %%
# Run query used in dbt modeling
df_result = spark.sql("""
SELECT 
    -- Reveneue grouping 
    PULocationID AS revenue_zone,
    date_trunc('month', pickup_datetime) AS revenue_month, 
    service_type, 

    -- Revenue calculation 
    SUM(fare_amount) AS revenue_monthly_fare,
    SUM(extra) AS revenue_monthly_extra,
    SUM(mta_tax) AS revenue_monthly_mta_tax,
    SUM(tip_amount) AS revenue_monthly_tip_amount,
    SUM(tolls_amount) AS revenue_monthly_tolls_amount,
    SUM(improvement_surcharge) AS revenue_monthly_improvement_surcharge,
    SUM(total_amount) AS revenue_monthly_total_amount,
    SUM(congestion_surcharge) AS revenue_monthly_congestion_surcharge,

    -- Additional calculations
    AVG(passenger_count) AS avg_montly_passenger_count,
    AVG(trip_distance) AS avg_montly_trip_distance
FROM
    trips_data
GROUP BY
    1, 2, 3
""")

# Show query results
df_result.show()
# Out:
# +------------+-------------------+------------+--------------------+---------------------+-----------------------+--------------------------+----------------------------+-------------------------------------+----------------------------+------------------------------------+--------------------------+------------------------+
# |revenue_zone|      revenue_month|service_type|revenue_monthly_fare|revenue_monthly_extra|revenue_monthly_mta_tax|revenue_monthly_tip_amount|revenue_monthly_tolls_amount|revenue_monthly_improvement_surcharge|revenue_monthly_total_amount|revenue_monthly_congestion_surcharge|avg_montly_passenger_count|avg_montly_trip_distance|
# +------------+-------------------+------------+--------------------+---------------------+-----------------------+--------------------------+----------------------------+-------------------------------------+----------------------------+------------------------------------+--------------------------+------------------------+
# |         127|2020-02-01 00:00:00|       green|  21571.680000000008|               890.75|                  495.0|                   1050.52|           488.8000000000003|                    345.0000000000035|          25119.149999999816|                               264.0|        1.1945837512537614|       4.583894472361811|
# |           9|2020-02-01 00:00:00|       green|   7251.639999999994|               643.25|                   25.0|         7.720000000000001|          183.20000000000005|                    77.99999999999984|           8193.510000000002|                                2.75|        1.1219512195121952|      445.80187969924833|
# |          47|2020-01-01 00:00:00|       green|  16630.150000000034|               1192.0|                  160.0|        42.230000000000004|           523.0000000000003|                   210.90000000000228|           18770.42999999991|                                11.0|         1.177685950413223|      4.6450000000000005|
# |         180|2020-02-01 00:00:00|       green|  2817.1500000000005|                178.0|                   15.0|                     12.52|                       37.47|                    30.00000000000003|          3090.1399999999985|                                 0.0|        1.0606060606060606|                  5.7353|
# |          53|2020-01-01 00:00:00|       green|   6281.649999999992|               330.25|                   49.0|         39.21999999999999|          102.50000000000001|                    68.39999999999971|           6873.770000000006|                                2.75|        1.2417582417582418|       6.929710743801653|
# |         128|2020-01-01 00:00:00|       green|  3261.3300000000004|                158.0|                   35.5|                     82.25|          104.04000000000002|                    34.50000000000003|           3714.020000000003|                                27.5|        1.0169491525423728|      7.0232800000000015|
# |         150|2020-01-01 00:00:00|       green|   9996.160000000005|                627.5|                   98.0|         97.86999999999999|          149.14000000000004|                   109.49999999999932|          11082.069999999976|                                 0.0|        1.1147540983606556|       5.393588516746412|
# |         263|2020-01-01 00:00:00|       green|   8987.339999999997|                561.0|                 124.55|        315.27000000000004|           335.0600000000002|                   127.19999999999915|           10684.16999999999|                              239.25|        1.4293478260869565|       5.264249422632796|
# |          19|2020-01-01 00:00:00|       green|   7798.880000000002|                377.0|                   42.0|                      6.66|          174.40000000000006|                    67.49999999999972|           8466.440000000008|                                 0.0|                  1.046875|      7.8507818930041156|
# |          81|2020-02-01 00:00:00|       green|   17340.13000000002|               1127.5|                  110.5|                     20.75|           991.5900000000004|                    149.3999999999993|          19743.770000000004|                                 0.0|        1.2653061224489797|       8.627810760667906|
# |          22|2020-02-01 00:00:00|       green|  17398.530000000006|               1148.5|                   99.5|         74.39999999999999|          478.57000000000016|                   164.99999999999915|           19367.24999999998|                                2.75|        1.1590909090909092|       6.001778523489931|
# |          40|2020-02-01 00:00:00|       green|  21840.030000000006|                896.5|                  831.0|        3179.4299999999994|           397.8000000000002|                    517.8000000000081|          28638.259999999806|                              967.75|        1.2492456246228123|      2.8544061962134237|
# |          37|2020-02-01 00:00:00|       green|  23375.710000000006|              1982.75|                  229.0|                    428.95|           527.5100000000002|                    284.1000000000018|           26942.41999999999|                              104.25|        1.2318059299191375|        4.49492110453649|
# |         186|2020-01-01 00:00:00|       green|  1539.2300000000002|                85.25|                    6.0|                       0.0|           97.92000000000002|                   13.800000000000011|                      1742.2|                                 0.0|        1.6666666666666667|       9.389565217391304|
# |          71|2020-02-01 00:00:00|       green|  26571.900000000085|               2603.5|                  195.0|                     30.23|          465.54000000000025|                    308.4000000000027|           30183.96999999992|                                 5.5|                    1.1875|       4.293813708260108|
# |          38|2020-02-01 00:00:00|       green|   8637.039999999988|               605.75|                   34.0|                       5.0|                      165.24|                    77.39999999999982|           9526.380000000005|                                 0.0|        1.2173913043478262|       8.019010989010992|
# |         216|2020-02-01 00:00:00|       green|  19758.420000000016|               1245.0|                  110.0|                    102.96|          424.25000000000017|                   195.29999999999984|          21843.379999999946|                                 5.5|        1.1793893129770991|       6.703884785819798|
# |         238|2020-01-01 00:00:00|       green|   5397.990000000001|                403.5|                   20.0|                       0.0|          124.68000000000002|                   61.199999999999775|           6007.370000000002|                                 0.0|                       1.2|       6.460536585365854|
# |         126|2020-01-01 00:00:00|       green|  11827.840000000017|               766.75|                  110.5|        101.86999999999999|           458.2800000000002|                    145.1999999999998|          13425.339999999993|                                11.0|                     1.275|       5.187806691449814|
# |         192|2020-02-01 00:00:00|       green|   6302.809999999998|               376.75|                   44.5|                    353.89|          54.129999999999995|                    71.69999999999989|           7220.180000000002|                                2.75|        1.2681159420289856|       5.143769230769231|
# +------------+-------------------+------------+--------------------+---------------------+-----------------------+--------------------------+----------------------------+-------------------------------------+----------------------------+------------------------------------+--------------------------+------------------------+
# only showing top 20 rows

# %%
# Write results to parquet using 1 partition
df_result.coalesce(1).write.parquet('data/report/revenue/', mode='overwrite')

# %% [markdown]
# ## Groupby in Spark

# %%
# Load libraries and create SparkSession
# Import libraries
import pandas as pd
import pyspark
import findspark
from pyspark.sql import SparkSession
from pyspark.sql import types
from pyspark.sql import functions as F

# Ensure that pyspark is available and that the environment variables are set
findspark.init()

# Create a SparkSession
spark = SparkSession.builder \
    .master("local[*]") \
    .appName('pyspark-sql') \
    .getOrCreate()

# %%
# Read green data and register as temporary table
df_green = spark.read.parquet("data/pq/green/*/*")
df_green.registerTempTable('green')
# Out:
# C:\tools\spark-3.3.2-bin-hadoop3\python\pyspark\sql\dataframe.py:229: FutureWarning: Deprecated in 2.0, use createOrReplaceTempView instead.
#   warnings.warn("Deprecated in 2.0, use createOrReplaceTempView instead.", FutureWarning)

# %%
# Execute a SQL query
df_green_revenue = spark.sql("""
SELECT 
    date_trunc('hour', lpep_pickup_datetime) AS hour, 
    PULocationID AS zone,

    SUM(total_amount) AS amount,
    COUNT(1) AS number_records
FROM
    green
WHERE
    lpep_pickup_datetime >= '2020-01-01 00:00:00'
GROUP BY
    1, 2
""")

# %%
# Write results to parquet using 20 partitions
df_green_revenue \
    .repartition(20) \
    .write.parquet('data/report/revenue/green', mode='overwrite')

# %%
# Read yellow data and register as temporary table
df_yellow = spark.read.parquet('data/pq/yellow/*/*')
df_yellow.registerTempTable('yellow')

# %%
# Get report revenue for yellow taxis
df_yellow_revenue = spark.sql("""
SELECT 
    date_trunc('hour', tpep_pickup_datetime) AS hour, 
    PULocationID AS zone,

    SUM(total_amount) AS amount,
    COUNT(1) AS number_records
FROM
    yellow
WHERE
    tpep_pickup_datetime >= '2020-01-01 00:00:00'
GROUP BY
    1, 2
""")

# %%
# Write results to parquet using 20 partitions
df_yellow_revenue \
    .repartition(20) \
    .write.parquet('data/report/revenue/yellow', mode='overwrite')

# %%
# Read back data from parquet
df_green_revenue = spark.read.parquet('data/report/revenue/green')
df_yellow_revenue = spark.read.parquet('data/report/revenue/yellow')
# Rename columns to join dataframes
df_green_revenue_tmp = df_green_revenue \
    .withColumnRenamed('amount', 'green_amount') \
    .withColumnRenamed('number_records', 'green_number_records')

df_yellow_revenue_tmp = df_yellow_revenue \
    .withColumnRenamed('amount', 'yellow_amount') \
    .withColumnRenamed('number_records', 'yellow_number_records')

# %%
# Perform an outer join on the dataframes
df_join = \
    df_green_revenue_tmp \
        .join(df_yellow_revenue_tmp, on=['hour', 'zone'], how='outer')

# %%
df_join.show()
# Out:
# +-------------------+----+------------------+--------------------+------------------+---------------------+
# |               hour|zone|      green_amount|green_number_records|     yellow_amount|yellow_number_records|
# +-------------------+----+------------------+--------------------+------------------+---------------------+
# |2020-01-01 00:00:00|  22|              15.8|                   1|              null|                 null|
# |2020-01-01 00:00:00|  25|             531.0|                  26|            324.35|                   16|
# |2020-01-01 00:00:00|  55|129.29000000000002|                   4|              null|                 null|
# |2020-01-01 00:00:00|  56|             99.69|                   3|              18.1|                    2|
# |2020-01-01 00:00:00|  60|            160.04|                   6|57.620000000000005|                    2|
# |2020-01-01 00:00:00|  61|            526.71|                  17|            146.64|                    3|
# |2020-01-01 00:00:00|  65|            199.49|                  10|            409.35|                   19|
# |2020-01-01 00:00:00|  71|              23.8|                   1|              null|                 null|
# |2020-01-01 00:00:00|  78|             34.46|                   2|              null|                 null|
# |2020-01-01 00:00:00|  88|              null|                null| 823.8000000000002|                   36|
# |2020-01-01 00:00:00| 106|             10.56|                   1|              null|                 null|
# |2020-01-01 00:00:00| 112|312.26000000000005|                  18|119.47999999999999|                    8|
# |2020-01-01 00:00:00| 113|              null|                null| 3984.319999999997|                  220|
# |2020-01-01 00:00:00| 148|              null|                null| 6790.150000000008|                  371|
# |2020-01-01 00:00:00| 161|              null|                null| 9410.210000000021|                  488|
# |2020-01-01 00:00:00| 162|              null|                null| 4622.289999999997|                  268|
# |2020-01-01 00:00:00| 185|              null|                null|             69.51|                    2|
# |2020-01-01 00:00:00| 190|             61.97|                   4|              54.1|                    3|
# |2020-01-01 00:00:00| 194|              null|                null|            148.71|                    2|
# |2020-01-01 00:00:00| 225|251.92000000000004|                  13|             74.07|                    3|
# +-------------------+----+------------------+--------------------+------------------+---------------------+
# only showing top 20 rows

# %%
# Write joined data
df_join.write.parquet('data/report/revenue/total', mode='overwrite')

# %%
# Read zones dataframe
df_zones = spark.read \
    .option("header", "true") \
    .csv('taxi+_zone_lookup.csv')
df_zones.write.parquet('zones')
df_zones = spark.read.parquet('zones')

# %%
# Merge large dataframe with small dataframe
# Merge total revenue with zone data
df_result = df_join.join(df_zones, df_join.zone == df_zones.LocationID)
# Write merged results to a parquet file
df_result.drop('LocationID', 'zone').write.parquet('tmp/revenue-zones')

# %% [markdown]
# ## RDDs operations - Map and Reduce

# %%
# Load libraries and create SparkSession
# Import libraries
import pandas as pd
import pyspark
import findspark
from pyspark.sql import SparkSession
from pyspark.sql import types
from pyspark.sql import functions as F
from datetime import datetime
from collections import namedtuple

# Ensure that pyspark is available and that the environment variables are set
findspark.init()

# Create a SparkSession
spark = SparkSession.builder \
    .master("local[*]") \
    .appName('rdd') \
    .getOrCreate()

# %%
# Read green data and transform it into an RDD object
df_green = spark.read.parquet('data/pq/green/*/*')
rdd = df_green \
    .select('lpep_pickup_datetime', 'PULocationID', 'total_amount') \
    .rdd

# %%
# Define functions to be used in the rdd methods

def filter_outliers(row):
    return row.lpep_pickup_datetime >= datetime(year=2020, month=1, day=1)

def prepare_for_grouping(row): 
    hour = row.lpep_pickup_datetime.replace(minute=0, second=0, microsecond=0)
    zone = row.PULocationID
    key = (hour, zone)
    
    amount = row.total_amount
    count = 1
    value = (amount, count)

    return (key, value)

def calculate_revenue(left_value, right_value):
    left_amount, left_count = left_value
    right_amount, right_count = right_value
    
    output_amount = left_amount + right_amount
    output_count = left_count + right_count
    
    return (output_amount, output_count)

def unwrap(row):
    RevenueRow = namedtuple('RevenueRow', ['hour', 'zone', 'revenue', 'count'])
    return RevenueRow(
        hour=row[0][0], 
        zone=row[0][1],
        revenue=row[1][0],
        count=row[1][1]
    )

# %%
# Define schema for the dataframe
result_schema = types.StructType([
    types.StructField('hour', types.TimestampType(), True),
    types.StructField('zone', types.IntegerType(), True),
    types.StructField('revenue', types.DoubleType(), True),
    types.StructField('count', types.IntegerType(), True)
])

# %%
# Apply RDD methods and write results to a dataframe
df_result = rdd \
    .filter(filter_outliers) \
    .map(prepare_for_grouping) \
    .reduceByKey(calculate_revenue) \
    .map(unwrap) \
    .toDF(result_schema) 

df_result.write.parquet('tmp/green-revenue')

# %% [markdown]
# ## RDDs operations - MapPartitions

# %%
import pandas as pd
columns = \
    ['VendorID', 'lpep_pickup_datetime', 'PULocationID',
    'DOLocationID', 'trip_distance']

duration_rdd = df_green \
    .select(columns) \
    .rdd

# %%
# Define ML simple model
def model_predict(df):
#     y_pred = model.predict(df)
    y_pred = df.trip_distance * 5
    return y_pred

# Define function to apply the model in batchs (each Spark partition). Partitions
# might not be balanced, so slicing (itertools.slice) each partition might be necessary.
def apply_model_in_batch(rows):
    df = pd.DataFrame(rows, columns=columns)
    predictions = model_predict(df)
    df['predicted_duration'] = predictions
    # It returns a generator that gathers the rows of the dataframe
    for row in df.itertuples():
        yield row

# %%
# Apply the ML model for each Spark partition using mapPartitions
df_predicts = duration_rdd \
    .mapPartitions(apply_model_in_batch)\
    .toDF() \
    .drop('Index')

df_predicts.select('predicted_duration').show()
# Out:
# +------------------+
# |predicted_duration|
# +------------------+
# |3.9000000000000004|
# |               4.9|
# |              13.5|
# |               4.0|
# |             11.65|
# |13.100000000000001|
# |5.6499999999999995|
# | 6.800000000000001|
# |             55.75|
# |               8.9|
# |               5.0|
# |             13.75|
# |               5.5|
# |             19.05|
# |              9.25|
# |              45.7|
# |               5.2|
# | 5.699999999999999|
# |              5.75|
# |4.6000000000000005|
# +------------------+
# only showing top 20 rows

# %%
spark.stop()

# %% [markdown]
# ## Spark in the Cloud

# %%
# Upload data to GCS
# !gsutil -m cp -r data/pq gs://dtc_data_lake_dtc-data-engineering-377412
# Out:
# Copying file://data\pq\green\2020\02\.part-00002-1775226c-d7af-47a0-9cf5-4953c84fb628-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\02\part-00001-1775226c-d7af-47a0-9cf5-4953c84fb628-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\02\._SUCCESS.crc [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\01\part-00001-4c35630f-8821-4e51-bbab-7b18067752cd-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\01\part-00003-4c35630f-8821-4e51-bbab-7b18067752cd-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\02\part-00002-1775226c-d7af-47a0-9cf5-4953c84fb628-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\02\.part-00003-1775226c-d7af-47a0-9cf5-4953c84fb628-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\01\_SUCCESS [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\01\.part-00001-4c35630f-8821-4e51-bbab-7b18067752cd-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\03\.part-00002-8a9d9513-8f1a-4dda-aad4-1694be1fdac2-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\01\.part-00003-4c35630f-8821-4e51-bbab-7b18067752cd-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\03\.part-00003-8a9d9513-8f1a-4dda-aad4-1694be1fdac2-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\02\.part-00000-1775226c-d7af-47a0-9cf5-4953c84fb628-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\03\.part-00001-8a9d9513-8f1a-4dda-aad4-1694be1fdac2-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\01\.part-00002-4c35630f-8821-4e51-bbab-7b18067752cd-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [0/380 files][    0.0 B/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\02\_SUCCESS [Content-Type=application/octet-stream]...
# / [0/380 files][ 22.2 KiB/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\01\part-00000-4c35630f-8821-4e51-bbab-7b18067752cd-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [0/380 files][ 22.2 KiB/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\01\.part-00000-4c35630f-8821-4e51-bbab-7b18067752cd-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\01\._SUCCESS.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\03\.part-00000-8a9d9513-8f1a-4dda-aad4-1694be1fdac2-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [0/380 files][ 22.2 KiB/  1.1 GiB]   0% Done
# / [0/380 files][ 22.2 KiB/  1.1 GiB]   0% Done
# / [0/380 files][ 22.2 KiB/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\01\part-00002-4c35630f-8821-4e51-bbab-7b18067752cd-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [0/380 files][342.2 KiB/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\02\.part-00001-1775226c-d7af-47a0-9cf5-4953c84fb628-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [0/380 files][342.2 KiB/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\02\part-00000-1775226c-d7af-47a0-9cf5-4953c84fb628-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [0/380 files][982.2 KiB/  1.1 GiB]   0% Done
# Copying file://data\pq\green\2020\02\part-00003-1775226c-d7af-47a0-9cf5-4953c84fb628-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [0/380 files][982.2 KiB/  1.1 GiB]   0% Done
# -
# - [1/380 files][ 12.8 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\03\._SUCCESS.crc [Content-Type=application/octet-stream]...
# - [1/380 files][ 13.1 MiB/  1.1 GiB]   1% Done
# - [2/380 files][ 13.4 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\03\part-00000-8a9d9513-8f1a-4dda-aad4-1694be1fdac2-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [2/380 files][ 13.7 MiB/  1.1 GiB]   1% Done
# - [3/380 files][ 13.7 MiB/  1.1 GiB]   1% Done
# - [4/380 files][ 14.0 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\03\part-00002-8a9d9513-8f1a-4dda-aad4-1694be1fdac2-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [4/380 files][ 14.0 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\03\part-00001-8a9d9513-8f1a-4dda-aad4-1694be1fdac2-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [4/380 files][ 14.4 MiB/  1.1 GiB]   1% Done
# - [5/380 files][ 14.4 MiB/  1.1 GiB]   1% Done
# - [6/380 files][ 14.4 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\03\_SUCCESS [Content-Type=application/octet-stream]...
# - [7/380 files][ 14.4 MiB/  1.1 GiB]   1% Done
# - [8/380 files][ 14.7 MiB/  1.1 GiB]   1% Done
# - [9/380 files][ 14.7 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\03\part-00003-8a9d9513-8f1a-4dda-aad4-1694be1fdac2-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\04\.part-00002-8834e04a-40ad-4a4e-84da-9b979d7e0992-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [9/380 files][ 14.7 MiB/  1.1 GiB]   1% Done
# - [9/380 files][ 14.7 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\04\.part-00001-8834e04a-40ad-4a4e-84da-9b979d7e0992-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\04\.part-00000-8834e04a-40ad-4a4e-84da-9b979d7e0992-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \
# \ [9/380 files][ 15.6 MiB/  1.1 GiB]   1% Done
# \ [9/380 files][ 15.6 MiB/  1.1 GiB]   1% Done
# \ [9/380 files][ 15.6 MiB/  1.1 GiB]   1% Done
# \ [10/380 files][ 16.2 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\04\.part-00003-8834e04a-40ad-4a4e-84da-9b979d7e0992-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \ [10/380 files][ 16.2 MiB/  1.1 GiB]   1% Done
# \ [11/380 files][ 16.8 MiB/  1.1 GiB]   1% Done
# \ [12/380 files][ 16.8 MiB/  1.1 GiB]   1% Done
# \ [13/380 files][ 17.1 MiB/  1.1 GiB]   1% Done
# \ [14/380 files][ 17.1 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\04\part-00000-8834e04a-40ad-4a4e-84da-9b979d7e0992-c000.snappy.parquet [Content-Type=application/octet-stream]...
# \ [15/380 files][ 17.1 MiB/  1.1 GiB]   1% Done
# \ [16/380 files][ 17.1 MiB/  1.1 GiB]   1% Done
# \ [17/380 files][ 17.1 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\04\_SUCCESS [Content-Type=application/octet-stream]...
# \ [17/380 files][ 17.4 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\04\part-00001-8834e04a-40ad-4a4e-84da-9b979d7e0992-c000.snappy.parquet [Content-Type=application/octet-stream]...
# \ [17/380 files][ 17.4 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\04\._SUCCESS.crc [Content-Type=application/octet-stream]...
# \ [17/380 files][ 17.4 MiB/  1.1 GiB]   1% Done
# \ [17/380 files][ 17.4 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\04\part-00003-8834e04a-40ad-4a4e-84da-9b979d7e0992-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\04\part-00002-8834e04a-40ad-4a4e-84da-9b979d7e0992-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\05\.part-00000-50c5c205-8948-4199-8ec8-6b667f8e098b-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\05\.part-00001-50c5c205-8948-4199-8ec8-6b667f8e098b-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\05\.part-00002-50c5c205-8948-4199-8ec8-6b667f8e098b-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \ [17/380 files][ 17.8 MiB/  1.1 GiB]   1% Done
# \ [17/380 files][ 17.8 MiB/  1.1 GiB]   1% Done
# \ [17/380 files][ 18.1 MiB/  1.1 GiB]   1% Done
# \ [18/380 files][ 18.4 MiB/  1.1 GiB]   1% Done
# \ [18/380 files][ 18.4 MiB/  1.1 GiB]   1% Done
# \ [19/380 files][ 20.2 MiB/  1.1 GiB]   1% Done
# \ [19/380 files][ 20.8 MiB/  1.1 GiB]   1% Done
# \ [20/380 files][ 20.8 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\05\.part-00003-50c5c205-8948-4199-8ec8-6b667f8e098b-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \ [20/380 files][ 20.8 MiB/  1.1 GiB]   1% Done
# Copying file://data\pq\green\2020\05\part-00000-50c5c205-8948-4199-8ec8-6b667f8e098b-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\05\._SUCCESS.crc [Content-Type=application/octet-stream]...
# \ [21/380 files][ 20.8 MiB/  1.1 GiB]   1% Done
# \ [22/380 files][ 20.8 MiB/  1.1 GiB]   1% Done
# \ [22/380 files][ 20.8 MiB/  1.1 GiB]   1% Done
# \ [22/380 files][ 20.8 MiB/  1.1 GiB]   1% Done
# \ [23/380 files][ 22.0 MiB/  1.1 GiB]   2% Done
# \ [24/380 files][ 22.0 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\05\part-00001-50c5c205-8948-4199-8ec8-6b667f8e098b-c000.snappy.parquet [Content-Type=application/octet-stream]...
# \ [24/380 files][ 22.3 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\05\part-00002-50c5c205-8948-4199-8ec8-6b667f8e098b-c000.snappy.parquet [Content-Type=application/octet-stream]...
# \ [24/380 files][ 22.3 MiB/  1.1 GiB]   2% Done
# \ [25/380 files][ 22.3 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\05\part-00003-50c5c205-8948-4199-8ec8-6b667f8e098b-c000.snappy.parquet [Content-Type=application/octet-stream]...
# \ [26/380 files][ 22.3 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\05\_SUCCESS [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\06\.part-00002-ffaeba45-6dc7-4eda-8b22-c1ea7e20f9e9-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\06\.part-00000-ffaeba45-6dc7-4eda-8b22-c1ea7e20f9e9-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \ [27/380 files][ 22.6 MiB/  1.1 GiB]   2% Done
# \ [27/380 files][ 23.0 MiB/  1.1 GiB]   2% Done
# \ [28/380 files][ 23.0 MiB/  1.1 GiB]   2% Done
# \ [29/380 files][ 23.0 MiB/  1.1 GiB]   2% Done
# \ [30/380 files][ 23.3 MiB/  1.1 GiB]   2% Done
# \ [31/380 files][ 23.3 MiB/  1.1 GiB]   2% Done
# \ [32/380 files][ 23.6 MiB/  1.1 GiB]   2% Done
# \ [32/380 files][ 23.6 MiB/  1.1 GiB]   2% Done
# \ [32/380 files][ 23.6 MiB/  1.1 GiB]   2% Done
# \ [32/380 files][ 23.8 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\06\part-00000-ffaeba45-6dc7-4eda-8b22-c1ea7e20f9e9-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\06\.part-00001-ffaeba45-6dc7-4eda-8b22-c1ea7e20f9e9-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\06\._SUCCESS.crc [Content-Type=application/octet-stream]...
# \ [32/380 files][ 24.4 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\06\.part-00003-ffaeba45-6dc7-4eda-8b22-c1ea7e20f9e9-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \ [32/380 files][ 24.4 MiB/  1.1 GiB]   2% Done
# \ [32/380 files][ 24.4 MiB/  1.1 GiB]   2% Done
# \ [32/380 files][ 24.4 MiB/  1.1 GiB]   2% Done
# |
# | [33/380 files][ 26.0 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\06\part-00001-ffaeba45-6dc7-4eda-8b22-c1ea7e20f9e9-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [33/380 files][ 26.0 MiB/  1.1 GiB]   2% Done
# | [34/380 files][ 26.9 MiB/  1.1 GiB]   2% Done
# | [35/380 files][ 26.9 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\06\part-00002-ffaeba45-6dc7-4eda-8b22-c1ea7e20f9e9-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [35/380 files][ 26.9 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\06\part-00003-ffaeba45-6dc7-4eda-8b22-c1ea7e20f9e9-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [35/380 files][ 27.2 MiB/  1.1 GiB]   2% Done
# | [36/380 files][ 27.2 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\06\_SUCCESS [Content-Type=application/octet-stream]...
# | [37/380 files][ 27.9 MiB/  1.1 GiB]   2% Done
# | [37/380 files][ 28.6 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\07\.part-00000-18bd7505-981b-4608-8f04-0e5e13b9fd42-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [38/380 files][ 28.6 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\07\.part-00001-18bd7505-981b-4608-8f04-0e5e13b9fd42-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [39/380 files][ 28.6 MiB/  1.1 GiB]   2% Done
# | [39/380 files][ 28.6 MiB/  1.1 GiB]   2% Done
# | [39/380 files][ 28.6 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\07\.part-00002-18bd7505-981b-4608-8f04-0e5e13b9fd42-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [39/380 files][ 28.6 MiB/  1.1 GiB]   2% Done
# | [40/380 files][ 28.6 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\07\.part-00003-18bd7505-981b-4608-8f04-0e5e13b9fd42-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [40/380 files][ 28.6 MiB/  1.1 GiB]   2% Done
# | [41/380 files][ 28.6 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\07\._SUCCESS.crc [Content-Type=application/octet-stream]...
# | [41/380 files][ 29.0 MiB/  1.1 GiB]   2% Done
# | [42/380 files][ 29.3 MiB/  1.1 GiB]   2% Done
# | [43/380 files][ 29.3 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\07\part-00001-18bd7505-981b-4608-8f04-0e5e13b9fd42-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\07\part-00000-18bd7505-981b-4608-8f04-0e5e13b9fd42-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [43/380 files][ 29.3 MiB/  1.1 GiB]   2% Done
# | [43/380 files][ 29.3 MiB/  1.1 GiB]   2% Done
# | [44/380 files][ 29.3 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\07\part-00002-18bd7505-981b-4608-8f04-0e5e13b9fd42-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [44/380 files][ 30.2 MiB/  1.1 GiB]   2% Done
# | [45/380 files][ 31.5 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\07\part-00003-18bd7505-981b-4608-8f04-0e5e13b9fd42-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [45/380 files][ 31.6 MiB/  1.1 GiB]   2% Done
# | [46/380 files][ 31.9 MiB/  1.1 GiB]   2% Done
# | [47/380 files][ 31.9 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\08\.part-00000-3f2ca15b-4cdd-43ae-928e-0e542ff04bb3-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\07\_SUCCESS [Content-Type=application/octet-stream]...
# | [47/380 files][ 31.9 MiB/  1.1 GiB]   2% Done
# | [47/380 files][ 31.9 MiB/  1.1 GiB]   2% Done
# | [48/380 files][ 31.9 MiB/  1.1 GiB]   2% Done
# | [49/380 files][ 31.9 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\08\.part-00001-3f2ca15b-4cdd-43ae-928e-0e542ff04bb3-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [50/380 files][ 31.9 MiB/  1.1 GiB]   2% Done
# | [51/380 files][ 31.9 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\08\.part-00002-3f2ca15b-4cdd-43ae-928e-0e542ff04bb3-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\08\.part-00003-3f2ca15b-4cdd-43ae-928e-0e542ff04bb3-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [51/380 files][ 32.2 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\08\._SUCCESS.crc [Content-Type=application/octet-stream]...
# | [51/380 files][ 32.5 MiB/  1.1 GiB]   2% Done
# | [51/380 files][ 32.5 MiB/  1.1 GiB]   2% Done
# | [51/380 files][ 32.5 MiB/  1.1 GiB]   2% Done
# | [52/380 files][ 32.5 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\08\part-00000-3f2ca15b-4cdd-43ae-928e-0e542ff04bb3-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [52/380 files][ 32.5 MiB/  1.1 GiB]   2% Done
# | [53/380 files][ 32.5 MiB/  1.1 GiB]   2% Done
# | [54/380 files][ 32.5 MiB/  1.1 GiB]   2% Done
# | [55/380 files][ 32.7 MiB/  1.1 GiB]   2% Done
# | [56/380 files][ 32.7 MiB/  1.1 GiB]   2% Done
# Copying file://data\pq\green\2020\08\part-00002-3f2ca15b-4cdd-43ae-928e-0e542ff04bb3-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [57/380 files][ 32.7 MiB/  1.1 GiB]   2% Done
# | [57/380 files][ 33.6 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\08\part-00003-3f2ca15b-4cdd-43ae-928e-0e542ff04bb3-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [57/380 files][ 33.9 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\08\part-00001-3f2ca15b-4cdd-43ae-928e-0e542ff04bb3-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\09\.part-00000-ba7fa881-cf4e-4084-93db-271cb19e4ae8-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [57/380 files][ 33.9 MiB/  1.1 GiB]   3% Done
# | [57/380 files][ 33.9 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\08\_SUCCESS [Content-Type=application/octet-stream]...
# | [57/380 files][ 33.9 MiB/  1.1 GiB]   3% Done
# | [58/380 files][ 34.2 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\09\.part-00001-ba7fa881-cf4e-4084-93db-271cb19e4ae8-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [58/380 files][ 35.5 MiB/  1.1 GiB]   3% Done
# | [59/380 files][ 35.7 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\09\.part-00002-ba7fa881-cf4e-4084-93db-271cb19e4ae8-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [59/380 files][ 35.7 MiB/  1.1 GiB]   3% Done
# | [60/380 files][ 35.7 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\09\.part-00003-ba7fa881-cf4e-4084-93db-271cb19e4ae8-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [60/380 files][ 35.7 MiB/  1.1 GiB]   3% Done
# | [61/380 files][ 36.0 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\09\._SUCCESS.crc [Content-Type=application/octet-stream]...
# | [61/380 files][ 36.0 MiB/  1.1 GiB]   3% Done
# | [62/380 files][ 36.0 MiB/  1.1 GiB]   3% Done
# | [63/380 files][ 36.0 MiB/  1.1 GiB]   3% Done
# | [64/380 files][ 36.0 MiB/  1.1 GiB]   3% Done
# | [65/380 files][ 36.0 MiB/  1.1 GiB]   3% Done
# | [66/380 files][ 36.0 MiB/  1.1 GiB]   3% Done
# | [67/380 files][ 36.0 MiB/  1.1 GiB]   3% Done
# | [68/380 files][ 36.0 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\09\part-00001-ba7fa881-cf4e-4084-93db-271cb19e4ae8-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\09\part-00002-ba7fa881-cf4e-4084-93db-271cb19e4ae8-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [68/380 files][ 36.2 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\09\part-00000-ba7fa881-cf4e-4084-93db-271cb19e4ae8-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [68/380 files][ 36.2 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\09\part-00003-ba7fa881-cf4e-4084-93db-271cb19e4ae8-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [68/380 files][ 36.2 MiB/  1.1 GiB]   3% Done
# | [68/380 files][ 36.2 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\10\.part-00001-449e56cb-872d-48cf-a497-674eb9a4fbd7-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [69/380 files][ 36.2 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\10\.part-00000-449e56cb-872d-48cf-a497-674eb9a4fbd7-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# /
# Copying file://data\pq\green\2020\09\_SUCCESS [Content-Type=application/octet-stream]...
# / [69/380 files][ 36.2 MiB/  1.1 GiB]   3% Done
# / [70/380 files][ 36.2 MiB/  1.1 GiB]   3% Done
# / [70/380 files][ 36.2 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\10\.part-00002-449e56cb-872d-48cf-a497-674eb9a4fbd7-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [71/380 files][ 36.2 MiB/  1.1 GiB]   3% Done
# / [71/380 files][ 36.6 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\10\.part-00003-449e56cb-872d-48cf-a497-674eb9a4fbd7-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [71/380 files][ 36.6 MiB/  1.1 GiB]   3% Done
# / [72/380 files][ 36.6 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\10\._SUCCESS.crc [Content-Type=application/octet-stream]...
# / [72/380 files][ 36.6 MiB/  1.1 GiB]   3% Done
# / [72/380 files][ 36.6 MiB/  1.1 GiB]   3% Done
# / [73/380 files][ 36.6 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\10\part-00000-449e56cb-872d-48cf-a497-674eb9a4fbd7-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [74/380 files][ 36.9 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\10\part-00001-449e56cb-872d-48cf-a497-674eb9a4fbd7-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [75/380 files][ 36.9 MiB/  1.1 GiB]   3% Done
# / [75/380 files][ 37.1 MiB/  1.1 GiB]   3% Done
# / [75/380 files][ 37.1 MiB/  1.1 GiB]   3% Done
# / [76/380 files][ 37.1 MiB/  1.1 GiB]   3% Done
# / [77/380 files][ 37.4 MiB/  1.1 GiB]   3% Done
# / [78/380 files][ 37.4 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\10\part-00002-449e56cb-872d-48cf-a497-674eb9a4fbd7-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [79/380 files][ 37.7 MiB/  1.1 GiB]   3% Done
# / [79/380 files][ 38.0 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\10\_SUCCESS [Content-Type=application/octet-stream]...
# / [79/380 files][ 38.0 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\10\part-00003-449e56cb-872d-48cf-a497-674eb9a4fbd7-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\11\.part-00002-7df94a6f-3da7-4a96-8c54-17cb569780ed-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [79/380 files][ 38.5 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\11\.part-00000-7df94a6f-3da7-4a96-8c54-17cb569780ed-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [80/380 files][ 38.5 MiB/  1.1 GiB]   3% Done
# / [80/380 files][ 38.5 MiB/  1.1 GiB]   3% Done
# / [80/380 files][ 38.5 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\11\.part-00001-7df94a6f-3da7-4a96-8c54-17cb569780ed-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [81/380 files][ 38.5 MiB/  1.1 GiB]   3% Done
# / [82/380 files][ 38.5 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\11\.part-00003-7df94a6f-3da7-4a96-8c54-17cb569780ed-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [82/380 files][ 38.8 MiB/  1.1 GiB]   3% Done
# / [82/380 files][ 38.8 MiB/  1.1 GiB]   3% Done
# / [83/380 files][ 38.8 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\11\part-00000-7df94a6f-3da7-4a96-8c54-17cb569780ed-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\11\part-00001-7df94a6f-3da7-4a96-8c54-17cb569780ed-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [84/380 files][ 39.4 MiB/  1.1 GiB]   3% Done
# / [84/380 files][ 39.4 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\11\._SUCCESS.crc [Content-Type=application/octet-stream]...
# / [84/380 files][ 39.4 MiB/  1.1 GiB]   3% Done
# / [84/380 files][ 39.4 MiB/  1.1 GiB]   3% Done
# / [85/380 files][ 39.7 MiB/  1.1 GiB]   3% Done
# / [86/380 files][ 40.0 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\11\part-00002-7df94a6f-3da7-4a96-8c54-17cb569780ed-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [87/380 files][ 40.3 MiB/  1.1 GiB]   3% Done
# / [87/380 files][ 40.3 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\11\_SUCCESS [Content-Type=application/octet-stream]...
# / [88/380 files][ 40.3 MiB/  1.1 GiB]   3% Done
# / [89/380 files][ 40.3 MiB/  1.1 GiB]   3% Done
# / [90/380 files][ 40.3 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\11\part-00003-7df94a6f-3da7-4a96-8c54-17cb569780ed-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [90/380 files][ 40.3 MiB/  1.1 GiB]   3% Done
# / [90/380 files][ 40.3 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\12\.part-00000-eb79afaa-338d-489e-8b3a-099ffb5ba045-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [90/380 files][ 40.6 MiB/  1.1 GiB]   3% Done
# / [91/380 files][ 40.6 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\12\.part-00002-eb79afaa-338d-489e-8b3a-099ffb5ba045-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [91/380 files][ 40.6 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\12\.part-00003-eb79afaa-338d-489e-8b3a-099ffb5ba045-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [91/380 files][ 40.6 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\12\.part-00001-eb79afaa-338d-489e-8b3a-099ffb5ba045-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [92/380 files][ 40.6 MiB/  1.1 GiB]   3% Done
# / [93/380 files][ 40.9 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\12\._SUCCESS.crc [Content-Type=application/octet-stream]...
# / [93/380 files][ 40.9 MiB/  1.1 GiB]   3% Done
# / [93/380 files][ 41.5 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\12\part-00000-eb79afaa-338d-489e-8b3a-099ffb5ba045-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\12\part-00001-eb79afaa-338d-489e-8b3a-099ffb5ba045-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [93/380 files][ 41.5 MiB/  1.1 GiB]   3% Done
# / [93/380 files][ 41.8 MiB/  1.1 GiB]   3% Done
# / [94/380 files][ 42.2 MiB/  1.1 GiB]   3% Done
# / [95/380 files][ 42.2 MiB/  1.1 GiB]   3% Done
# / [96/380 files][ 42.2 MiB/  1.1 GiB]   3% Done
# / [97/380 files][ 42.2 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\12\part-00002-eb79afaa-338d-489e-8b3a-099ffb5ba045-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2020\12\part-00003-eb79afaa-338d-489e-8b3a-099ffb5ba045-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [98/380 files][ 42.2 MiB/  1.1 GiB]   3% Done
# / [99/380 files][ 42.5 MiB/  1.1 GiB]   3% Done
# / [100/380 files][ 42.5 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2021\01\.part-00000-a77c916a-419d-4cf4-8bfa-dd8c69e6fbcc-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [101/380 files][ 42.5 MiB/  1.1 GiB]   3% Done
# / [101/380 files][ 42.5 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2021\01\.part-00003-a77c916a-419d-4cf4-8bfa-dd8c69e6fbcc-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [101/380 files][ 42.5 MiB/  1.1 GiB]   3% Done
# / [101/380 files][ 42.8 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2020\12\_SUCCESS [Content-Type=application/octet-stream]...
# / [101/380 files][ 42.8 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2021\01\.part-00001-a77c916a-419d-4cf4-8bfa-dd8c69e6fbcc-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [101/380 files][ 42.8 MiB/  1.1 GiB]   3% Done
# / [101/380 files][ 42.8 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2021\01\.part-00002-a77c916a-419d-4cf4-8bfa-dd8c69e6fbcc-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [101/380 files][ 43.4 MiB/  1.1 GiB]   3% Done
# Copying file://data\pq\green\2021\01\._SUCCESS.crc [Content-Type=application/octet-stream]...
# / [101/380 files][ 43.4 MiB/  1.1 GiB]   3% Done
# -
# - [102/380 files][ 44.8 MiB/  1.1 GiB]   4% Done
# - [103/380 files][ 44.8 MiB/  1.1 GiB]   4% Done
# - [104/380 files][ 44.8 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\01\part-00000-a77c916a-419d-4cf4-8bfa-dd8c69e6fbcc-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [105/380 files][ 44.8 MiB/  1.1 GiB]   4% Done
# - [105/380 files][ 44.8 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\01\part-00001-a77c916a-419d-4cf4-8bfa-dd8c69e6fbcc-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [105/380 files][ 44.8 MiB/  1.1 GiB]   4% Done
# - [106/380 files][ 44.8 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\01\part-00003-a77c916a-419d-4cf4-8bfa-dd8c69e6fbcc-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2021\01\part-00002-a77c916a-419d-4cf4-8bfa-dd8c69e6fbcc-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [106/380 files][ 45.1 MiB/  1.1 GiB]   4% Done
# - [106/380 files][ 45.1 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\01\_SUCCESS [Content-Type=application/octet-stream]...
# - [107/380 files][ 45.4 MiB/  1.1 GiB]   4% Done
# - [108/380 files][ 45.4 MiB/  1.1 GiB]   4% Done
# - [109/380 files][ 45.7 MiB/  1.1 GiB]   4% Done
# - [109/380 files][ 45.7 MiB/  1.1 GiB]   4% Done
# - [110/380 files][ 45.7 MiB/  1.1 GiB]   4% Done
# - [111/380 files][ 46.0 MiB/  1.1 GiB]   4% Done
# - [112/380 files][ 46.0 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\02\.part-00000-74981afa-3950-4310-a84b-92473b6a9393-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [112/380 files][ 46.0 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\02\.part-00001-74981afa-3950-4310-a84b-92473b6a9393-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2021\02\.part-00002-74981afa-3950-4310-a84b-92473b6a9393-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2021\02\.part-00003-74981afa-3950-4310-a84b-92473b6a9393-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [112/380 files][ 46.0 MiB/  1.1 GiB]   4% Done
# - [112/380 files][ 46.0 MiB/  1.1 GiB]   4% Done
# - [112/380 files][ 46.0 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\02\part-00000-74981afa-3950-4310-a84b-92473b6a9393-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2021\02\._SUCCESS.crc [Content-Type=application/octet-stream]...
# - [112/380 files][ 46.7 MiB/  1.1 GiB]   4% Done
# - [112/380 files][ 46.7 MiB/  1.1 GiB]   4% Done
# - [113/380 files][ 47.3 MiB/  1.1 GiB]   4% Done
# - [114/380 files][ 47.3 MiB/  1.1 GiB]   4% Done
# - [115/380 files][ 47.3 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\02\part-00001-74981afa-3950-4310-a84b-92473b6a9393-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [116/380 files][ 47.6 MiB/  1.1 GiB]   4% Done
# - [117/380 files][ 47.6 MiB/  1.1 GiB]   4% Done
# - [117/380 files][ 47.6 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\02\part-00002-74981afa-3950-4310-a84b-92473b6a9393-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [118/380 files][ 47.8 MiB/  1.1 GiB]   4% Done
# - [119/380 files][ 47.8 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\02\part-00003-74981afa-3950-4310-a84b-92473b6a9393-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [119/380 files][ 47.8 MiB/  1.1 GiB]   4% Done
# - [120/380 files][ 47.8 MiB/  1.1 GiB]   4% Done
# - [120/380 files][ 47.8 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\02\_SUCCESS [Content-Type=application/octet-stream]...
# - [121/380 files][ 47.8 MiB/  1.1 GiB]   4% Done
# - [121/380 files][ 48.1 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\03\.part-00000-03a4b987-2932-45c2-8a34-752fd25b5384-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2021\03\.part-00002-03a4b987-2932-45c2-8a34-752fd25b5384-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [121/380 files][ 48.7 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\03\.part-00001-03a4b987-2932-45c2-8a34-752fd25b5384-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [122/380 files][ 48.7 MiB/  1.1 GiB]   4% Done
# - [122/380 files][ 48.7 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\03\._SUCCESS.crc [Content-Type=application/octet-stream]...
# - [122/380 files][ 48.7 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\03\.part-00003-03a4b987-2932-45c2-8a34-752fd25b5384-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [122/380 files][ 48.7 MiB/  1.1 GiB]   4% Done
# - [123/380 files][ 48.7 MiB/  1.1 GiB]   4% Done
# - [123/380 files][ 48.7 MiB/  1.1 GiB]   4% Done
# - [124/380 files][ 48.7 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\03\part-00001-03a4b987-2932-45c2-8a34-752fd25b5384-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2021\03\part-00000-03a4b987-2932-45c2-8a34-752fd25b5384-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [124/380 files][ 49.6 MiB/  1.1 GiB]   4% Done
# - [124/380 files][ 49.6 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\03\part-00002-03a4b987-2932-45c2-8a34-752fd25b5384-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [124/380 files][ 49.6 MiB/  1.1 GiB]   4% Done
# - [125/380 files][ 50.2 MiB/  1.1 GiB]   4% Done
# - [126/380 files][ 50.4 MiB/  1.1 GiB]   4% Done
# - [127/380 files][ 50.4 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\03\part-00003-03a4b987-2932-45c2-8a34-752fd25b5384-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2021\03\_SUCCESS [Content-Type=application/octet-stream]...
# - [127/380 files][ 51.1 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\04\.part-00000-ead2aa50-e231-4460-b7b8-fa843530e0a1-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [127/380 files][ 51.1 MiB/  1.1 GiB]   4% Done
# - [127/380 files][ 51.1 MiB/  1.1 GiB]   4% Done
# - [128/380 files][ 51.1 MiB/  1.1 GiB]   4% Done
# - [129/380 files][ 51.1 MiB/  1.1 GiB]   4% Done
# - [130/380 files][ 51.1 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\04\.part-00002-ead2aa50-e231-4460-b7b8-fa843530e0a1-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2021\04\.part-00001-ead2aa50-e231-4460-b7b8-fa843530e0a1-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [131/380 files][ 51.1 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\04\.part-00003-ead2aa50-e231-4460-b7b8-fa843530e0a1-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [132/380 files][ 51.1 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\04\part-00002-ead2aa50-e231-4460-b7b8-fa843530e0a1-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [133/380 files][ 51.1 MiB/  1.1 GiB]   4% Done
# - [134/380 files][ 51.1 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\04\._SUCCESS.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2021\04\part-00000-ead2aa50-e231-4460-b7b8-fa843530e0a1-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [134/380 files][ 51.1 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\04\part-00001-ead2aa50-e231-4460-b7b8-fa843530e0a1-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [135/380 files][ 51.4 MiB/  1.1 GiB]   4% Done
# - [135/380 files][ 51.7 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\04\part-00003-ead2aa50-e231-4460-b7b8-fa843530e0a1-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [135/380 files][ 51.7 MiB/  1.1 GiB]   4% Done
# - [135/380 files][ 51.7 MiB/  1.1 GiB]   4% Done
# - [135/380 files][ 51.7 MiB/  1.1 GiB]   4% Done
# - [135/380 files][ 51.9 MiB/  1.1 GiB]   4% Done
# - [135/380 files][ 52.0 MiB/  1.1 GiB]   4% Done
# - [135/380 files][ 52.0 MiB/  1.1 GiB]   4% Done
# - [136/380 files][ 52.3 MiB/  1.1 GiB]   4% Done
# - [137/380 files][ 52.3 MiB/  1.1 GiB]   4% Done
# - [138/380 files][ 52.3 MiB/  1.1 GiB]   4% Done
# - [139/380 files][ 52.3 MiB/  1.1 GiB]   4% Done
# - [140/380 files][ 52.6 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\05\.part-00001-0642282c-b24e-4969-bf93-2a5a2fdeaf7d-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [141/380 files][ 52.8 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\05\.part-00000-0642282c-b24e-4969-bf93-2a5a2fdeaf7d-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [141/380 files][ 52.8 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\05\.part-00003-0642282c-b24e-4969-bf93-2a5a2fdeaf7d-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [141/380 files][ 52.9 MiB/  1.1 GiB]   4% Done
# - [141/380 files][ 52.9 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\05\._SUCCESS.crc [Content-Type=application/octet-stream]...
# Copying file://data\pq\green\2021\04\_SUCCESS [Content-Type=application/octet-stream]...
# - [141/380 files][ 52.9 MiB/  1.1 GiB]   4% Done
# - [141/380 files][ 52.9 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\05\.part-00002-0642282c-b24e-4969-bf93-2a5a2fdeaf7d-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# - [141/380 files][ 52.9 MiB/  1.1 GiB]   4% Done
# \
# \ [142/380 files][ 52.9 MiB/  1.1 GiB]   4% Done
# Copying file://data\pq\green\2021\05\part-00000-0642282c-b24e-4969-bf93-2a5a2fdeaf7d-c000.snappy.parquet [Content-Type=application/octet-stream]...
# ...
# - [311/380 files][594.2 MiB/  1.1 GiB]  54% Done  38.8 MiB/s ETA 00:00:13
# Copying file://data\pq\yellow\2021\03\._SUCCESS.crc [Content-Type=application/octet-stream]...
# - [311/380 files][596.1 MiB/  1.1 GiB]  54% Done  39.1 MiB/s ETA 00:00:13
# - [312/380 files][596.8 MiB/  1.1 GiB]  54% Done  39.1 MiB/s ETA 00:00:13
# Copying file://data\pq\yellow\2021\03\part-00000-30e8078a-b420-4da8-b8f0-2be1dcd8d14b-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [312/380 files][596.8 MiB/  1.1 GiB]  54% Done  39.1 MiB/s ETA 00:00:13
# - [313/380 files][598.0 MiB/  1.1 GiB]  54% Done  38.7 MiB/s ETA 00:00:13
# Copying file://data\pq\yellow\2021\03\part-00001-30e8078a-b420-4da8-b8f0-2be1dcd8d14b-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [313/380 files][598.4 MiB/  1.1 GiB]  54% Done  38.7 MiB/s ETA 00:00:13
# - [314/380 files][598.7 MiB/  1.1 GiB]  54% Done  38.7 MiB/s ETA 00:00:13
# Copying file://data\pq\yellow\2021\03\part-00002-30e8078a-b420-4da8-b8f0-2be1dcd8d14b-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [314/380 files][599.3 MiB/  1.1 GiB]  54% Done  38.7 MiB/s ETA 00:00:13
# - [315/380 files][601.5 MiB/  1.1 GiB]  54% Done  38.7 MiB/s ETA 00:00:13
# Copying file://data\pq\yellow\2021\03\part-00003-30e8078a-b420-4da8-b8f0-2be1dcd8d14b-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [315/380 files][601.8 MiB/  1.1 GiB]  54% Done  38.8 MiB/s ETA 00:00:13
# \
# \ [316/380 files][609.9 MiB/  1.1 GiB]  55% Done  38.3 MiB/s ETA 00:00:13
# Copying file://data\pq\yellow\2021\03\_SUCCESS [Content-Type=application/octet-stream]...
# \ [316/380 files][609.9 MiB/  1.1 GiB]  55% Done  38.3 MiB/s ETA 00:00:13
# \ [317/380 files][615.5 MiB/  1.1 GiB]  56% Done  38.2 MiB/s ETA 00:00:13
# Copying file://data\pq\yellow\2021\04\.part-00000-4099b5de-eded-4ee3-8474-7ceb53c4fd20-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \ [317/380 files][616.4 MiB/  1.1 GiB]  56% Done  38.4 MiB/s ETA 00:00:12
# \ [318/380 files][622.4 MiB/  1.1 GiB]  56% Done  38.4 MiB/s ETA 00:00:12
# Copying file://data\pq\yellow\2021\04\.part-00001-4099b5de-eded-4ee3-8474-7ceb53c4fd20-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \ [318/380 files][622.7 MiB/  1.1 GiB]  56% Done  38.5 MiB/s ETA 00:00:12
# \ [319/380 files][628.4 MiB/  1.1 GiB]  57% Done  38.3 MiB/s ETA 00:00:12
# Copying file://data\pq\yellow\2021\04\.part-00002-4099b5de-eded-4ee3-8474-7ceb53c4fd20-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \ [319/380 files][629.4 MiB/  1.1 GiB]  57% Done  38.5 MiB/s ETA 00:00:12
# |
# | [320/380 files][635.7 MiB/  1.1 GiB]  58% Done  38.7 MiB/s ETA 00:00:12
# Copying file://data\pq\yellow\2021\04\.part-00003-4099b5de-eded-4ee3-8474-7ceb53c4fd20-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [320/380 files][636.1 MiB/  1.1 GiB]  58% Done  38.8 MiB/s ETA 00:00:12
# | [321/380 files][637.7 MiB/  1.1 GiB]  58% Done  38.6 MiB/s ETA 00:00:12
# Copying file://data\pq\yellow\2021\04\._SUCCESS.crc [Content-Type=application/octet-stream]...
# | [321/380 files][637.7 MiB/  1.1 GiB]  58% Done  38.6 MiB/s ETA 00:00:12
# | [322/380 files][644.2 MiB/  1.1 GiB]  58% Done  38.8 MiB/s ETA 00:00:12
# Copying file://data\pq\yellow\2021\04\part-00000-4099b5de-eded-4ee3-8474-7ceb53c4fd20-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [322/380 files][644.2 MiB/  1.1 GiB]  58% Done  38.9 MiB/s ETA 00:00:12
# | [323/380 files][644.5 MiB/  1.1 GiB]  58% Done  38.9 MiB/s ETA 00:00:12
# Copying file://data\pq\yellow\2021\04\part-00001-4099b5de-eded-4ee3-8474-7ceb53c4fd20-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [323/380 files][644.5 MiB/  1.1 GiB]  58% Done  38.9 MiB/s ETA 00:00:12
# /
# / [324/380 files][662.0 MiB/  1.1 GiB]  60% Done  38.8 MiB/s ETA 00:00:11
# Copying file://data\pq\yellow\2021\04\part-00002-4099b5de-eded-4ee3-8474-7ceb53c4fd20-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [324/380 files][662.3 MiB/  1.1 GiB]  60% Done  38.9 MiB/s ETA 00:00:11
# / [325/380 files][675.0 MiB/  1.1 GiB]  61% Done  38.1 MiB/s ETA 00:00:11
# Copying file://data\pq\yellow\2021\04\part-00003-4099b5de-eded-4ee3-8474-7ceb53c4fd20-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [325/380 files][675.0 MiB/  1.1 GiB]  61% Done  38.1 MiB/s ETA 00:00:11
# -
# \
# \ [326/380 files][708.3 MiB/  1.1 GiB]  64% Done  39.1 MiB/s ETA 00:00:10
# Copying file://data\pq\yellow\2021\04\_SUCCESS [Content-Type=application/octet-stream]...
# \ [326/380 files][708.3 MiB/  1.1 GiB]  64% Done  39.1 MiB/s ETA 00:00:10
# \ [327/380 files][716.4 MiB/  1.1 GiB]  65% Done  39.5 MiB/s ETA 00:00:10
# \ [328/380 files][716.4 MiB/  1.1 GiB]  65% Done  39.5 MiB/s ETA 00:00:10
# Copying file://data\pq\yellow\2021\05\.part-00000-99895ee9-ce63-4b2d-a4e0-b2028550ba8e-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \ [328/380 files][716.4 MiB/  1.1 GiB]  65% Done  39.6 MiB/s ETA 00:00:10
# Copying file://data\pq\yellow\2021\05\.part-00001-99895ee9-ce63-4b2d-a4e0-b2028550ba8e-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \ [328/380 files][716.6 MiB/  1.1 GiB]  65% Done  39.5 MiB/s ETA 00:00:10
# \ [329/380 files][723.2 MiB/  1.1 GiB]  66% Done  39.5 MiB/s ETA 00:00:09
# Copying file://data\pq\yellow\2021\05\.part-00002-99895ee9-ce63-4b2d-a4e0-b2028550ba8e-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \ [329/380 files][723.8 MiB/  1.1 GiB]  66% Done  39.6 MiB/s ETA 00:00:09
# \ [330/380 files][726.8 MiB/  1.1 GiB]  66% Done  39.6 MiB/s ETA 00:00:09
# \ [331/380 files][726.8 MiB/  1.1 GiB]  66% Done  39.6 MiB/s ETA 00:00:09
# Copying file://data\pq\yellow\2021\05\._SUCCESS.crc [Content-Type=application/octet-stream]...
# \ [331/380 files][727.2 MiB/  1.1 GiB]  66% Done  39.6 MiB/s ETA 00:00:09
# Copying file://data\pq\yellow\2021\05\.part-00003-99895ee9-ce63-4b2d-a4e0-b2028550ba8e-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# \ [331/380 files][727.2 MiB/  1.1 GiB]  66% Done  39.6 MiB/s ETA 00:00:09
# |
# | [332/380 files][731.7 MiB/  1.1 GiB]  66% Done  39.6 MiB/s ETA 00:00:09
# Copying file://data\pq\yellow\2021\05\part-00000-99895ee9-ce63-4b2d-a4e0-b2028550ba8e-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [332/380 files][732.3 MiB/  1.1 GiB]  66% Done  39.7 MiB/s ETA 00:00:09
# | [333/380 files][732.9 MiB/  1.1 GiB]  66% Done  39.8 MiB/s ETA 00:00:09
# Copying file://data\pq\yellow\2021\05\part-00001-99895ee9-ce63-4b2d-a4e0-b2028550ba8e-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [333/380 files][732.9 MiB/  1.1 GiB]  66% Done  39.8 MiB/s ETA 00:00:09
# | [334/380 files][736.0 MiB/  1.1 GiB]  67% Done  39.8 MiB/s ETA 00:00:09
# Copying file://data\pq\yellow\2021\05\part-00002-99895ee9-ce63-4b2d-a4e0-b2028550ba8e-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [334/380 files][736.0 MiB/  1.1 GiB]  67% Done  39.8 MiB/s ETA 00:00:09
# | [335/380 files][740.3 MiB/  1.1 GiB]  67% Done  39.4 MiB/s ETA 00:00:09
# Copying file://data\pq\yellow\2021\05\part-00003-99895ee9-ce63-4b2d-a4e0-b2028550ba8e-c000.snappy.parquet [Content-Type=application/octet-stream]...
# | [335/380 files][740.3 MiB/  1.1 GiB]  67% Done  39.4 MiB/s ETA 00:00:09
# | [336/380 files][743.5 MiB/  1.1 GiB]  67% Done  39.7 MiB/s ETA 00:00:09
# Copying file://data\pq\yellow\2021\05\_SUCCESS [Content-Type=application/octet-stream]...
# | [336/380 files][743.5 MiB/  1.1 GiB]  67% Done  39.7 MiB/s ETA 00:00:09
# | [337/380 files][749.4 MiB/  1.1 GiB]  68% Done  39.3 MiB/s ETA 00:00:09
# Copying file://data\pq\yellow\2021\06\.part-00000-f2e4d84d-8af9-4d9c-9c56-a7256c3fdfac-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [337/380 files][749.7 MiB/  1.1 GiB]  68% Done  39.5 MiB/s ETA 00:00:09
# | [338/380 files][753.8 MiB/  1.1 GiB]  68% Done  39.5 MiB/s ETA 00:00:09
# /
# Copying file://data\pq\yellow\2021\06\.part-00001-f2e4d84d-8af9-4d9c-9c56-a7256c3fdfac-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [338/380 files][755.0 MiB/  1.1 GiB]  68% Done  39.7 MiB/s ETA 00:00:09
# / [339/380 files][759.6 MiB/  1.1 GiB]  69% Done  39.4 MiB/s ETA 00:00:09
# Copying file://data\pq\yellow\2021\06\.part-00002-f2e4d84d-8af9-4d9c-9c56-a7256c3fdfac-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [339/380 files][759.9 MiB/  1.1 GiB]  69% Done  39.4 MiB/s ETA 00:00:08
# / [340/380 files][760.4 MiB/  1.1 GiB]  69% Done  39.2 MiB/s ETA 00:00:09
# Copying file://data\pq\yellow\2021\06\.part-00003-f2e4d84d-8af9-4d9c-9c56-a7256c3fdfac-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [340/380 files][760.4 MiB/  1.1 GiB]  69% Done  39.2 MiB/s ETA 00:00:09
# / [341/380 files][765.5 MiB/  1.1 GiB]  69% Done  39.2 MiB/s ETA 00:00:08
# Copying file://data\pq\yellow\2021\06\._SUCCESS.crc [Content-Type=application/octet-stream]...
# / [341/380 files][766.2 MiB/  1.1 GiB]  70% Done  39.3 MiB/s ETA 00:00:08
# / [342/380 files][769.9 MiB/  1.1 GiB]  70% Done  39.1 MiB/s ETA 00:00:08
# Copying file://data\pq\yellow\2021\06\part-00000-f2e4d84d-8af9-4d9c-9c56-a7256c3fdfac-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [342/380 files][770.2 MiB/  1.1 GiB]  70% Done  39.1 MiB/s ETA 00:00:08
# / [343/380 files][771.1 MiB/  1.1 GiB]  70% Done  39.3 MiB/s ETA 00:00:08
# Copying file://data\pq\yellow\2021\06\part-00001-f2e4d84d-8af9-4d9c-9c56-a7256c3fdfac-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [343/380 files][771.4 MiB/  1.1 GiB]  70% Done  39.4 MiB/s ETA 00:00:08
# / [344/380 files][771.4 MiB/  1.1 GiB]  70% Done  39.1 MiB/s ETA 00:00:08
# / [345/380 files][771.4 MiB/  1.1 GiB]  70% Done  39.1 MiB/s ETA 00:00:08
# Copying file://data\pq\yellow\2021\06\part-00002-f2e4d84d-8af9-4d9c-9c56-a7256c3fdfac-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [345/380 files][772.1 MiB/  1.1 GiB]  70% Done  39.2 MiB/s ETA 00:00:08
# Copying file://data\pq\yellow\2021\06\part-00003-f2e4d84d-8af9-4d9c-9c56-a7256c3fdfac-c000.snappy.parquet [Content-Type=application/octet-stream]...
# / [345/380 files][772.1 MiB/  1.1 GiB]  70% Done  39.1 MiB/s ETA 00:00:08
# -
# \
# \ [345/380 files][811.4 MiB/  1.1 GiB]  74% Done  39.4 MiB/s ETA 00:00:07
# \ [346/380 files][817.7 MiB/  1.1 GiB]  74% Done  39.1 MiB/s ETA 00:00:07
# Copying file://data\pq\yellow\2021\06\_SUCCESS [Content-Type=application/octet-stream]...
# \ [346/380 files][817.7 MiB/  1.1 GiB]  74% Done  39.1 MiB/s ETA 00:00:07
# |
# | [347/380 files][824.5 MiB/  1.1 GiB]  75% Done  38.7 MiB/s ETA 00:00:07
# Copying file://data\pq\yellow\2021\07\.part-00000-32883e8f-a9b8-44cf-bbe4-cbc3cb73dc1d-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [347/380 files][824.8 MiB/  1.1 GiB]  75% Done  39.2 MiB/s ETA 00:00:07
# | [348/380 files][840.0 MiB/  1.1 GiB]  76% Done  38.6 MiB/s ETA 00:00:07
# Copying file://data\pq\yellow\2021\07\.part-00001-32883e8f-a9b8-44cf-bbe4-cbc3cb73dc1d-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# | [348/380 files][840.0 MiB/  1.1 GiB]  76% Done  38.6 MiB/s ETA 00:00:07
# /
# / [349/380 files][847.0 MiB/  1.1 GiB]  77% Done  38.4 MiB/s ETA 00:00:06
# Copying file://data\pq\yellow\2021\07\.part-00002-32883e8f-a9b8-44cf-bbe4-cbc3cb73dc1d-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [349/380 files][847.9 MiB/  1.1 GiB]  77% Done  38.6 MiB/s ETA 00:00:06
# / [350/380 files][859.1 MiB/  1.1 GiB]  78% Done  38.4 MiB/s ETA 00:00:06
# Copying file://data\pq\yellow\2021\07\.part-00003-32883e8f-a9b8-44cf-bbe4-cbc3cb73dc1d-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# / [350/380 files][859.7 MiB/  1.1 GiB]  78% Done  38.3 MiB/s ETA 00:00:06
# -
# - [351/380 files][866.4 MiB/  1.1 GiB]  79% Done  38.4 MiB/s ETA 00:00:06
# Copying file://data\pq\yellow\2021\07\._SUCCESS.crc [Content-Type=application/octet-stream]...
# - [351/380 files][866.4 MiB/  1.1 GiB]  79% Done  38.4 MiB/s ETA 00:00:06
# - [352/380 files][868.3 MiB/  1.1 GiB]  79% Done  38.7 MiB/s ETA 00:00:06
# Copying file://data\pq\yellow\2021\07\part-00000-32883e8f-a9b8-44cf-bbe4-cbc3cb73dc1d-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [352/380 files][868.9 MiB/  1.1 GiB]  79% Done  38.8 MiB/s ETA 00:00:06
# - [353/380 files][871.1 MiB/  1.1 GiB]  79% Done  37.7 MiB/s ETA 00:00:06
# Copying file://data\pq\yellow\2021\07\part-00001-32883e8f-a9b8-44cf-bbe4-cbc3cb73dc1d-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [353/380 files][871.7 MiB/  1.1 GiB]  79% Done  37.8 MiB/s ETA 00:00:06
# - [354/380 files][873.9 MiB/  1.1 GiB]  79% Done  38.0 MiB/s ETA 00:00:06
# Copying file://data\pq\yellow\2021\07\part-00002-32883e8f-a9b8-44cf-bbe4-cbc3cb73dc1d-c000.snappy.parquet [Content-Type=application/octet-stream]...
# - [354/380 files][874.8 MiB/  1.1 GiB]  79% Done  38.0 MiB/s ETA 00:00:06
# \
# \ [355/380 files][890.8 MiB/  1.1 GiB]  81% Done  37.3 MiB/s ETA 00:00:05
# Copying file://data\pq\yellow\2021\07\part-00003-32883e8f-a9b8-44cf-bbe4-cbc3cb73dc1d-c000.snappy.parquet [Content-Type=application/octet-stream]...
# \ [355/380 files][891.4 MiB/  1.1 GiB]  81% Done  37.3 MiB/s ETA 00:00:05
# \ [356/380 files][905.2 MiB/  1.1 GiB]  82% Done  37.8 MiB/s ETA 00:00:05
# Copying file://data\pq\yellow\2021\07\_SUCCESS [Content-Type=application/octet-stream]...
# \ [356/380 files][905.2 MiB/  1.1 GiB]  82% Done  37.8 MiB/s ETA 00:00:05
# \ [357/380 files][908.9 MiB/  1.1 GiB]  83% Done  37.9 MiB/s ETA 00:00:05
# \ [358/380 files][913.6 MiB/  1.1 GiB]  83% Done  38.2 MiB/s ETA 00:00:05
# |
# | [359/380 files][934.9 MiB/  1.1 GiB]  85% Done  38.8 MiB/s ETA 00:00:04
# | [360/380 files][936.5 MiB/  1.1 GiB]  85% Done  38.6 MiB/s ETA 00:00:04
# /
# / [361/380 files][944.9 MiB/  1.1 GiB]  86% Done  38.7 MiB/s ETA 00:00:04
# / [362/380 files][970.6 MiB/  1.1 GiB]  88% Done  39.8 MiB/s ETA 00:00:03
# -
# - [363/380 files][984.0 MiB/  1.1 GiB]  89% Done  40.1 MiB/s ETA 00:00:03
# - [364/380 files][988.1 MiB/  1.1 GiB]  90% Done  40.2 MiB/s ETA 00:00:03
# - [365/380 files][990.3 MiB/  1.1 GiB]  90% Done  40.4 MiB/s ETA 00:00:03
# \
# \ [366/380 files][ 1020 MiB/  1.1 GiB]  93% Done  41.0 MiB/s ETA 00:00:02
# |
# | [367/380 files][  1.0 GiB/  1.1 GiB]  93% Done  41.1 MiB/s ETA 00:00:02
# | [368/380 files][  1.0 GiB/  1.1 GiB]  93% Done  41.1 MiB/s ETA 00:00:02
# | [369/380 files][  1.0 GiB/  1.1 GiB]  94% Done  41.3 MiB/s ETA 00:00:01
# | [370/380 files][  1.0 GiB/  1.1 GiB]  95% Done  41.1 MiB/s ETA 00:00:01
# /
# -
# - [371/380 files][  1.0 GiB/  1.1 GiB]  97% Done  41.0 MiB/s ETA 00:00:01
# - [372/380 files][  1.0 GiB/  1.1 GiB]  97% Done  41.1 MiB/s ETA 00:00:01
# - [373/380 files][  1.0 GiB/  1.1 GiB]  98% Done  41.0 MiB/s ETA 00:00:00
# - [374/380 files][  1.0 GiB/  1.1 GiB]  98% Done  40.9 MiB/s ETA 00:00:00
# \
# \ [375/380 files][  1.1 GiB/  1.1 GiB]  99% Done  40.4 MiB/s ETA 00:00:00
# \ [376/380 files][  1.1 GiB/  1.1 GiB]  99% Done  40.4 MiB/s ETA 00:00:00
# \ [377/380 files][  1.1 GiB/  1.1 GiB]  99% Done  40.3 MiB/s ETA 00:00:00
# \ [378/380 files][  1.1 GiB/  1.1 GiB]  99% Done  39.9 MiB/s ETA 00:00:00
# \ [379/380 files][  1.1 GiB/  1.1 GiB]  99% Done  37.5 MiB/s ETA 00:00:00
# |
# | [380/380 files][  1.1 GiB/  1.1 GiB] 100% Done  36.9 MiB/s ETA 00:00:00
#
# Operation completed over 380 objects/1.1 GiB.

# %%
# 1) Download the GCS connector for Hadoop - 
# we need to tell Spark how to access GCS
# !gsutil cp gs://hadoop-lib/gcs/gcs-connector-hadoop3-2.2.5.jar C:\tools\gcs-connector-hadoop3-2.2.5.jar
# Out:
# Copying gs://hadoop-lib/gcs/gcs-connector-hadoop3-2.2.5.jar...
# / [0 files][    0.0 B/ 30.1 MiB]
# -
# - [0 files][  9.4 MiB/ 30.1 MiB]
# \
# \ [1 files][ 30.1 MiB/ 30.1 MiB]
#
# Operation completed over 1 objects/30.1 MiB.

# %%
# 3) Create a SparkSession with the GCS connector
import pyspark
import findspark
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
from pyspark.context import SparkContext

# Ensure that pyspark is available and that the environment variables are set
findspark.init()

# Setting the credentials for GCS and the GCS connector
credentials_location = ".\\.gc\\ny-rides.json"

conf = SparkConf() \
    .setMaster('local[*]') \
    .setAppName('test') \
    .set("spark.jars", "C:\\tools\\gcs-connector-hadoop3-2.2.5.jar") \
    .set("spark.hadoop.google.cloud.auth.service.account.enable", "true") \
    .set("spark.hadoop.google.cloud.auth.service.account.json.keyfile", credentials_location)

# %%
# 4) Set the Spark Context: tell Hadoop to use the GCS connector and the credentials
sc = SparkContext(conf=conf)

hadoop_conf = sc._jsc.hadoopConfiguration()

hadoop_conf.set("fs.AbstractFileSystem.gs.impl",  "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFS")
hadoop_conf.set("fs.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem")
hadoop_conf.set("fs.gs.auth.service.account.json.keyfile", credentials_location)
hadoop_conf.set("fs.gs.auth.service.account.enable", "true")

# %%
# 5) Create a SparkSession
spark = SparkSession.builder \
    .config(conf=sc.getConf()) \
    .getOrCreate()

# %%
# Read data from GCS and show first 5 rows
df_green = spark.read.parquet('gs://dtc_data_lake_dtc-data-engineering-377412/pq/green/*/*')
df_green.head(5)

# %%
spark.stop()

# %% [markdown]
# ## Creating a local Spark cluster - standalone mode

# %%
# Load libraries and create SparkSession
# Import libraries
import pandas as pd
import pyspark
import findspark
from pyspark.sql import SparkSession

# Ensure that pyspark is available and that the environment variables are set
findspark.init()

# Create a SparkSession
spark = SparkSession.builder \
    .master("spark://localhost:7077") \
    .appName('standalone') \
    .getOrCreate()

# %%
# Check that Spark Standalone is running and working properly
df_green = spark.read.parquet('data/pq/green/*/*')
df_green.head()
# Out:
# Row(VendorID=2, lpep_pickup_datetime=datetime.datetime(2020, 1, 12, 18, 15, 4), lpep_dropoff_datetime=datetime.datetime(2020, 1, 12, 18, 19, 52), store_and_fwd_flag='N', RatecodeID=1, PULocationID=41, DOLocationID=41, passenger_count=1, trip_distance=0.78, fare_amount=5.5, extra=0.0, mta_tax=0.5, tip_amount=1.58, tolls_amount=0.0, ehail_fee=None, improvement_surcharge=0.3, total_amount=7.88, payment_type=1, trip_type=1, congestion_surcharge=0.0)

# %%
# Run Python script in Spark Standalone
# !python test_spark_sql.py \
    --input_green=data/pq/green/2020/*/ \
    --input_yellow=data/pq/yellow/2020/*/ \
    --output=data/report-2020
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
#
# [Stage 0:>                                                          (0 + 1) / 1]
#
#
# C:\tools\spark-3.3.2-bin-hadoop3\python\pyspark\sql\dataframe.py:229: FutureWarning: Deprecated in 2.0, use createOrReplaceTempView instead.
#   warnings.warn("Deprecated in 2.0, use createOrReplaceTempView instead.", FutureWarning)
#
# [Stage 2:>                                                         (0 + 8) / 17]
#
# [Stage 2:>                                                         (0 + 9) / 17]
#
# [Stage 2:=============>                                            (4 + 8) / 17]
#
# [Stage 2:=================>                                        (5 + 8) / 17]
#
# [Stage 2:=======================>                                  (7 + 8) / 17]
#
# [Stage 2:===========================>                              (8 + 8) / 17]
#
# [Stage 2:==============================>                           (9 + 8) / 17]
#
# [Stage 2:========================================>                (12 + 5) / 17]
#
# [Stage 2:===========================================>             (13 + 4) / 17]
#
# [Stage 2:==================================================>      (15 + 2) / 17]
#
# [Stage 2:=====================================================>   (16 + 1) / 17]
#
# [Stage 4:>                                                          (0 + 1) / 1]
# 23/03/05 22:55:43 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# SUCCESS: The process with PID 16528 (child process of PID 1044) has been terminated.
# SUCCESS: The process with PID 1044 (child process of PID 19472) has been terminated.
# SUCCESS: The process with PID 19472 (child process of PID 16016) has been terminated.

# %%
# Run Python script in Spark Standalone
# !python test_spark_sql.py \
    --input_green=data/pq/green/2021/*/ \
    --input_yellow=data/pq/yellow/2021/*/ \
    --output=data/report-2021
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
#
# [Stage 0:>                                                          (0 + 1) / 1]
#
#
# C:\tools\spark-3.3.2-bin-hadoop3\python\pyspark\sql\dataframe.py:229: FutureWarning: Deprecated in 2.0, use createOrReplaceTempView instead.
#   warnings.warn("Deprecated in 2.0, use createOrReplaceTempView instead.", FutureWarning)
#
# [Stage 2:>                                                         (0 + 8) / 17]
#
# [Stage 2:===>                                                      (1 + 8) / 17]
#
# [Stage 2:======>                                                   (2 + 8) / 17]
#
# [Stage 2:==========>                                               (3 + 8) / 17]
#
# [Stage 2:==========>                                               (3 + 9) / 17]
#
# [Stage 2:=================>                                        (5 + 8) / 17]
#
# [Stage 2:====================>                                     (6 + 8) / 17]
#
# [Stage 2:====================>                                     (6 + 9) / 17]
#
# [Stage 2:=======================>                                  (7 + 8) / 17]
#
# [Stage 2:===========================>                              (8 + 8) / 17]
#
# [Stage 2:==============================>                           (9 + 8) / 17]
#
# [Stage 2:=================================>                       (10 + 7) / 17]
#
# [Stage 2:====================================>                    (11 + 6) / 17]
#
# [Stage 2:===========================================>             (13 + 4) / 17]
#
# [Stage 2:==================================================>      (15 + 2) / 17]
#
# [Stage 2:=====================================================>   (16 + 1) / 17]
#
# [Stage 4:>                                                          (0 + 1) / 1]
# 23/03/06 00:29:52 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# SUCCESS: The process with PID 16092 (child process of PID 1232) has been terminated.
# SUCCESS: The process with PID 1232 (child process of PID 7100) has been terminated.
# SUCCESS: The process with PID 7100 (child process of PID 8504) has been terminated.

# %% [markdown]
# Use spark-submit for running Python scripts in Spark Standalone
# Before running this, you should stop the standalone application created above
# Run this on CMD, following the next steps:
# - Make sure the PYSPARK_PYTHON env variable is correctly set up.
#     - Check where python
#     - Set the first value of where python (Python path of the corresponding environment) as PYSPARK_PYTHON: `set PYSPARK_PYTHON=C:\Users\aarro\anaconda3\envs\de-zoomcamp2\python.exe`
# - cd to the corresponding folder and execute the spark-submit command. The master and a worker have to be set up previously, check
# ```cmd
# spark-submit ^
#     --master="spark://localhost:7077" ^
#     test_spark_sql.py ^
#         --input_green=data/pq/green/2021/*/ ^
#         --input_yellow=data/pq/yellow/2021/*/ ^
#         --output=data/report-2021
# ```

# %%
spark.stop()
